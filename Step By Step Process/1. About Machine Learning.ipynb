# %% [markdown]
# ## What is Machine Learning?

# %% [markdown]
# Machine learning is a branch of artificial intelligence (AI) and computer science which focuses on the use of data and algorithms to imitate the way that humans learn, gradually improving its accuracy.

# %% [markdown]
# ### Major Steps of learning Machine Learning or to implement Machine Learning are:-

# %%
# !pip install graphviz
# Out:
# ...
#      ---------------------------------------- 47.0/47.0 kB ? eta 0:00:00
# ...

# %%
import graphviz
f = graphviz.Digraph(filename = "C:\\Users\\004GX3744\\Desktop\\Machine Learning\\Steps.gv")
main = ["m1","m2","m3","m4","m5","m6","m7","m8"]
Types = ["Machine Learning", "Collecting Data","Data Preprocessing","Choosing a Model","Training the Model","Evaluating the Model","Parameter Tuning","Making Predictions"]
for name, position in zip(main, Types):
     f.node(name, position,shape="box")
 
#Specify edges
f.edge("m1","m2");
f.edge("m4","m5")
f.edge("m5","m6"); f.edge("m6","m7"); f.edge("m7","m8");

m1 = ["m11","m12","m13","m14"]
m1types = ["Open Source Datasets","Web Scraping","Synthetic Datasets","Manual Data Generation"]
for name, position in zip(m1, m1types):
     f.node(name, position,shape="box")
f.edge("m2","m11"); f.edge("m2","m12")
f.edge("m2","m13"); f.edge("m2","m14")
f.edge("m11","m3"); f.edge("m12","m3")
f.edge("m13","m3"); f.edge("m14","m3")

m2 = ["m21","m22","m23","m24"]
m2types = ["Data Cleaning","Data Transformation","Data Reduction","Other Methods"]


# m2types = ["Handling\nmissing\nData","Creating\nCategories","Creating\nNew\nFeatures",
#            "Converting\nFeatures\ninto\nNumeric","Removal of\nNoisy\nData",
#            "Plot\ndifferent\nfeatures\nagainst\none\nanother","Encode\nCategorical\ndata",
#            "Splitting\ndata\ninto\nTraining\nand\nTest\nData","Feature\nScaling"]

for name, position in zip(m2, m2types):
     f.node(name, position,shape="box")
        

f.edge("m3","m21"); f.edge("m3","m22")
f.edge("m3","m23"); f.edge("m3","m24")
f.edge("m24","m4");




m21 = ["m211","m212","m213"]
m21types = ["Missing Values","Smothening\nof\nNoisy Data","Removing Outliers"]


for name, position in zip(m21, m21types):
     f.node(name, position,shape="box")
        

f.edge("m21","m211"); f.edge("m21","m212")
f.edge("m21","m213");
f.edge("m213","m22")


m211 = ["m2111","m2112"]
m211types = ["Deletion","Imputation"]

for name, position in zip(m211, m211types):
     f.node(name, position,shape="box")

f.edge("m211","m2111"); f.edge("m211","m2112")
f.edge("m2111","m22"); f.edge("m2112","m22")

        
m212 = ["m2121"]
m212types = ["Binning"]

for name, position in zip(m212, m212types):
     f.node(name, position,shape="box")

f.edge("m212","m2121");
f.edge("m2121","m22");


m23 = ["m221","m222","m223","m224"]
m23types = ["Feature Scaling\nOR\nNormalization"]


for name, position in zip(m23, m23types):
     f.node(name, position,shape="box")
        

f.edge("m22","m221"); 

m232 = ["m2211","m2212","m2213"]
m232types = ["Min-Max\nNormalization","Z-Score\nNormalization\nOR\nStandardization","Robust\nScaling"]

for name, position in zip(m232, m232types):
     f.node(name, position,shape="box")

f.edge("m221","m2211"); f.edge("m221","m2212")
f.edge("m221","m2213")
f.edge("m2211","m23"); f.edge("m2212","m23")
f.edge("m2213","m23")


m233 = ["m2331","m2332"]
m233types = ["Feature\nSelection","Dimensionality\nReduction"]

for name, position in zip(m233, m233types):
     f.node(name, position,shape="box")

f.edge("m23","m2331"); f.edge("m23","m2332")
f.edge("m2331","m24"); f.edge("m2332","m24")


    
f
# f.view()
# print(f.source) 

# filename = f.render(filename='img/g1')

# pylab.savefig('filename.png')
